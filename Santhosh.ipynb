# %% [markdown]
# # AssignmentLecture2ConceptsIP_2017

# %% [markdown]
# # EQUALIZE_HIST
#
#
# Syntax : equalize_hist(image, nbins=128, mask=0)
#
#
# Parameters :
#
#
# 1)image : array
#
#
# 2)nbins : int (This represents the Number of bins for image histogram and this argument is ignored for integer images, for which each integer is its own bin )
#
#
# 3)mask: array of bools or 0s and 1s (Array of same shape as image.Only points at which mask == True
# are used for the equalization, which is applied to the whole image)
#
#
#
# Explanation :
#
#
# Equalize_hist function performs histogram equalization. It enhances the contrast of images by transforming the values in an intensity image so that the histogram of the output image approximately matches a specified histogram (uniform distribution by default). This Histogram Equalization is operated on the entire image.

# %% [markdown]
# # EQUALIZE_ADAPTHIST
#
#
# Syntax : skimage.exposure.equalize_adapthist(image, kernel_size=None, clip_limit=0.1, nbins=128)
#
#
# Parameters :
#
#
# 1)image : (M, N, [C]) ndarray
#
#
# 2)kernel_size: integer or list-like (It defines the shape of contextual regions used in the algorithm )
#
#
# 3)clip_limit : float (Clipping limit, normalized between 0 and 1 (higher values give more contrast))
#
#
# 4)nbins : int (Number of gray bins for histogram (“data range”))
#
#
#
#
# Explanation :
#
#
# Equalize_adapthist performs contrast-limited adaptive histogram equalization. Unlike histeq, it operates on small data regions (tiles) rather than the entire image. Each tile's contrast is enhanced so that the histogram of each output region approximately matches the specified histogram (uniform distribution by default).

# %% [markdown]
# # Histogram Equalization Vs Adaptive Histogram Equalization
#
#
#
# The Adaptive Histogram Equalization can be useful over Standard Histogram Equalization when there is a need for observing Smaller details in an image.
#
#
#
# With respect to Anatomy, every element off a Medical Image is considered to be Important and therefore Adaptive Histogram Equalization is preferred rather than Standard Histogram Equalization.

# %% [markdown]
# # 02 INVESTIGATION ASSIGNMENT

# %% [markdown]
# # IMAGE ENHANCEMENT TECHNIQUE
#
# The principle objective of Image Enhancement Techniques is to process an image so that the result is more suitable than the original image for a specific application.

# %% [markdown]
# # Median Filtering
#
#
# Median Filtering and Average filtering are most widely used techniques for the removal of Salt and Pepper Noises from an Image.
#
#
# These two types of filtering both set the value of the output pixel to the average of the pixel values in the neighborhood around the corresponding input pixel.
#
#
# However, with median filtering, the value of an output pixel is determined by the median of the neighborhood pixels, rather than the mean. The median is much less sensitive than the mean to extreme values (called outliers).
#
#
# Median filtering is therefore better able to remove these outliers without reducing the sharpness of the image.
#
#
#
# Median filtering is a specific case of order-statistic filtering, also known as rank filtering.

# %% [markdown]
# a)Median Filtering is useful in the Salt and Pepper Noise Removal of an image
#
#
#
# Example :
#
#
#
# Let us consider an original image to which Salt and Pepper Noise is added  as follows
#
#
#
# I = imread('eight.tif')  (#Original Image)
#
#
#
# J = imnoise(I,'salt & pepper',0.02) (#Added Noise)
#
#
#
# Kmedian = medfilt2(J)    (#Filtering of the image)
#
#
#
# Here,we consider 'I' to be a Desired Medical Image to which 'J' is assumedd to be Noise from other Factors.
#
#
#
# Now ,after Applying the Median Filterinng to that orignnal image, the image obtained will be a Noise less image.
#
#
#
#
# b)The function "medfilt2(J)" is the function used in Python for Median Filtering.
#
#
#
# Syntax :
#
#
#
# Kmedian = medfilt2(J)
#
#
#
#
#
# Parameters :
#
#
#
# J = imnoise(I,'salt & pepper',0.02) is the Salt ad Pepper Noise that is added to the Original Image for which Median Filtering is applied.
#
#
#
#
#
#
#
# c)Yes.This technique can be widely applied in the medical Imaging because, in the Medical applications  the Desired Signal may be interefered by an Unwanted Signals.Therefore ,Noise Removal plays a major part in order to obtain the Actual or the Desired part of a signal.
#
#
#
#
#
#
#
#
# d)"An Improved Median Filtering Algorithm for Image Noise Reduction"     (http://www.sciencedirect.com/science/article/pii/S1875389212005494) by
#
#
#
#
#
#  1)YoulianZhu,ChengHuang
# College of Electronic Information Engineering Jiangsu Teachers University of Technology Changzhou, China, 213001
